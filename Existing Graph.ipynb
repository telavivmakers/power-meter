# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import re
import json

# %%
with open('wattometer.log', 'r') as f:
    lines = f.readlines()

# %%
vals = [json.loads(re.search(r'\[\d+, \d+, \d+\]', x.strip()).group(0)) for x in lines]

# %%
print(vals[-10:])
# Out:
# [[528, 1117, 765], [558, 1076, 1882], [619, 1095, 1892], [570, 1081, 2207], [562, 1062, 1401], [520, 1101, 764], [550, 1087, 757], [504, 1110, 768], [540, 1104, 757], [533, 1128, 758]]

# %%
fnx = lambda : np.random.randint(5, 50, 10)
y = np.row_stack((fnx(), fnx(), fnx()))
x = np.arange(461034)

# %%
leads = list(zip(*vals))
print(len(leads[1]))
# Out:
# 461034

# %%
fig, ax = plt.subplots(figsize=(40,5))
ax.stackplot(x, *leads, linewidth=0)
plt.show()
